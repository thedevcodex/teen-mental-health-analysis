# %%
import pandas as pd

# %%
df = pd.read_csv("Teen_Mental_Health_Dataset-selected-columns.csv")

# %%
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level
# 0                      low             2
# 1                     high             8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1200 non-null   int64
#  1   gender                    1200 non-null   object
#  2   daily_social_media_hours  1200 non-null   float64
#  3   platform_usage            1200 non-null   object
#  4   sleep_hours               1200 non-null   float64
#  5   screen_time_before_sleep  1200 non-null   float64
#  6   academic_performance      1200 non-null   float64
#  7   physical_activity         1200 non-null   float64
#  8   social_interaction_level  1200 non-null   object
#  9   stress_level              1200 non-null   int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 93.9+ KB

# %%
df.describe(include="all")
# Out:
#                 age gender  daily_social_media_hours platform_usage  \
# count   1200.000000   1200               1200.000000           1200
# unique          NaN      2                       NaN              3
# top             NaN   male                       NaN      Instagram
# freq            NaN    615                       NaN            411
# mean      15.928333    NaN                  4.536667            NaN
# std        2.021947    NaN                  2.029599            NaN
# min       13.000000    NaN                  1.000000            NaN
# 25%       14.000000    NaN                  2.800000            NaN
# 50%       16.000000    NaN                  4.500000            NaN
# 75%       18.000000    NaN                  6.300000            NaN
# max       19.000000    NaN                  8.000000            NaN
#
#         sleep_hours  screen_time_before_sleep  academic_performance  \
# count   1200.000000               1200.000000           1200.000000
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'daily_social_media_hours', 'platform_usage',
#        'sleep_hours', 'screen_time_before_sleep', 'academic_performance',
#        'physical_activity', 'social_interaction_level', 'stress_level'],
#       dtype='object')

# %% [markdown]
# # Average Social Media Platform Usage

# %%
df.groupby('platform_usage')['daily_social_media_hours'].mean().reset_index()
# Out:
#   platform_usage  daily_social_media_hours
# 0           Both                  4.518414
# 1      Instagram                  4.559367
# 2         TikTok                  4.531156

# %% [markdown]
# # Age Wise Stress Level

# %%
df.groupby('age')['stress_level'].mean().reset_index()
# Out:
#    age  stress_level
# 0   13      5.460000
# 1   14      6.176471
# 2   15      5.133333
# 3   16      5.453988
# 4   17      5.170588
# 5   18      5.203488
# 6   19      5.623457

# %% [markdown]
# # Age wise Average Social Media Hours

# %%
df.groupby('age')['daily_social_media_hours'].mean().reset_index()
# Out:
#    age  daily_social_media_hours
# 0   13                  4.511000
# 1   14                  4.350980
# 2   15                  4.717222
# 3   16                  4.636810
# 4   17                  4.763529
# 5   18                  4.242442
# 6   19                  4.516667

# %% [markdown]
# # Gender Wise Average Social Media Hours

# %%
df.groupby('gender')['daily_social_media_hours'].mean().reset_index()
# Out:
#    gender  daily_social_media_hours
# 0  female                  4.512991
# 1    male                  4.559187

# %% [markdown]
# # Age wise Average Sleep Hours

# %%
df.groupby('age')['sleep_hours'].mean().reset_index()
# Out:
#    age  sleep_hours
# 0   13     6.485500
# 1   14     6.315686
# 2   15     6.493889
# 3   16     6.485890
# 4   17     6.505882
# 5   18     6.359884
# 6   19     6.480864

# %% [markdown]
# # Gender Wise Average stress Level

# %%
df.groupby('gender')['stress_level'].mean().reset_index()
# Out:
#    gender  stress_level
# 0  female      5.422222
# 1    male      5.468293

# %% [markdown]
# # Gender Wise Sleep Hours

# %%
df.groupby('gender')['sleep_hours'].mean().reset_index()
# Out:
#    gender  sleep_hours
# 0  female     6.496410
# 1    male     6.404715

# %% [markdown]
# # Social Interaction Wise Average Stress Level

# %%
df.groupby('social_interaction_level')['stress_level'].mean().reset_index()
# Out:
#   social_interaction_level  stress_level
# 0                     high      5.512195
# 1                      low      5.349398
# 2                   medium      5.483173

# %%
from sqlalchemy import create_engine

# Mysql connection
username = "root"
password = "coder"
host = "localhost"
port = "3306"
database = "socialmedia"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

table_name = "teen_analyze"
df.to_sql(table_name, engine , if_exists="replace", index=False)
pd.read_sql("Select*from teen_analyze limit 5;",engine)
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level
# 0                      low             2
# 1                     high             8
# ...
